# %%
import pandas as pd
columns = ['target', 'cap-shape', 'cap-surface', 'cap-color', 'bruises?', 'odor', 'gill-attachment' ,'gill-spacing' , 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']
df = pd.read_csv('agaricus-lepiota.txt', delimiter=',', names=columns)
df.head()
# Out:
#   target cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0      p         x           s         n        t    p               f
# 1      e         x           s         y        t    a               f
# 2      e         b           s         w        t    l               f
# 3      p         x           y         w        t    p               f
# 4      e         x           s         g        f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
from pycaret.classification import *

# %%
experiment = setup(df, target='target')
# Out:
# <style type="text/css">
# #T_02409_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_02409">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02409_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_02409_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02409_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02409_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_02409_row0_col1" class="data row0 col1" >3365</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02409_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_02409_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02409_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_02409_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02409_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_02409_row3_col1" class="data row3 col1" >e: 0, p: 1</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_02409_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_02409_row4_col1" class="data row4 col1" >(8124, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_02409_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_02409_row5_col1" class="data row5 col1" >(8124, 113)</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_02409_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_02409_row6_col1" class="data row6 col1" >(5686, 113)</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_02409_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_02409_row7_col1" class="data row7 col1" >(2438, 113)</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_02409_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_02409_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_02409_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_02409_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_02409_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_02409_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_02409_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_02409_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_02409_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_02409_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_02409_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_02409_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_02409_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_02409_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_02409_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_02409_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_02409_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_02409_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_02409_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_02409_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_02409_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_02409_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_02409_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_02409_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_02409_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_02409_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_02409_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_02409_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_02409_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_02409_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_02409_row22_col1" class="data row22 col1" >ad61</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_d0ba8 th {
#   text-align: left;
# }
# #T_d0ba8_row0_col0, #T_d0ba8_row1_col0, #T_d0ba8_row1_col2, #T_d0ba8_row2_col0, #T_d0ba8_row3_col0, #T_d0ba8_row4_col0, #T_d0ba8_row5_col0, #T_d0ba8_row5_col1, #T_d0ba8_row5_col2, #T_d0ba8_row5_col3, #T_d0ba8_row5_col5, #T_d0ba8_row5_col6, #T_d0ba8_row5_col7, #T_d0ba8_row6_col0, #T_d0ba8_row6_col1, #T_d0ba8_row6_col3, #T_d0ba8_row6_col5, #T_d0ba8_row6_col6, #T_d0ba8_row6_col7, #T_d0ba8_row7_col0, #T_d0ba8_row7_col1, #T_d0ba8_row7_col2, #T_d0ba8_row7_col3, #T_d0ba8_row7_col5, #T_d0ba8_row7_col6, #T_d0ba8_row7_col7, #T_d0ba8_row8_col0, #T_d0ba8_row8_col1, #T_d0ba8_row8_col2, #T_d0ba8_row8_col3, #T_d0ba8_row8_col5, #T_d0ba8_row8_col6, #T_d0ba8_row8_col7, #T_d0ba8_row9_col0, #T_d0ba8_row9_col1, #T_d0ba8_row9_col3, #T_d0ba8_row9_col5, #T_d0ba8_row9_col6, #T_d0ba8_row9_col7, #T_d0ba8_row10_col0, #T_d0ba8_row10_col1, #T_d0ba8_row10_col2, #T_d0ba8_row10_col3, #T_d0ba8_row10_col5, #T_d0ba8_row10_col6, #T_d0
_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_d0ba8_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_d0ba8_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_d0ba8_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_d0ba8_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_d0ba8_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_d0ba8_row1_col8" class="data row1 col8" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_d0ba8_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_d0ba8_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_d0ba8_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_d0ba8_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_d0ba8_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_d0ba8_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_d0ba8_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_d0ba8_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_d0ba8_row2_col8" class="data row2 col8" >0.4960</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_d0ba8_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_d0ba8_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_d0ba8_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_d0ba8_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_d0ba8_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_d0ba8_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_d0ba8_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_d0ba8_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_d0ba8_row3_col8" class="data row3 col8" >0.5180</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_d0ba8_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d0ba8_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_d0ba8_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_d0ba8_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_d0ba8_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_d0ba8_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_d0ba8_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_d0ba8_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_d0ba8_row4_col8" class="data row4 col8" >0.5840</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_d0ba8_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_d0ba8_row5_col1" class="data row5 col1" >0.9998</td>
#       <td id="T_d0ba8_row5_col2" class="data row5 col2" >0.9998</td>
#       <td id="T_d0ba8_row5_col3" class="data row5 col3" >0.9996</td>
#       <td id="T_d0ba8_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_d0ba8_row5_col5" class="data row5 col5" >0.9998</td>
#       <td id="T_d0ba8_row5_col6" class="data row5 col6" >0.9996</td>
#       <td id="T_d0ba8_row5_col7" class="data row5 col7" >0.9996</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
predict_model(best_model, df.tail())
# Out:
#      cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 8119         k           s         n        f    n               a
# 8120         x           s         n        f    n               a
# 8121         f           s         n        f    n               a
# 8122         k           y         n        f    y               f
# 8123         x           s         n        f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ... veil-type veil-color  \
# 8119            c         b          y           e  ...         p          o
# 8120            c         b          y           e  ...         p          n
# 8121            c         b          n           e  ...         p          o
# 8122            c         n          b           t  ...         p          w
# 8123            c         b          y           e  ...         p          o
#
#      ring-number ring-type spore-print-color population habitat target  \
# 8119           o         p                 b          c       l      0
# 8120           o         p                 b          v       l      0
# 8121           o         p                 b          c       l      0
# 8122           o         e                 w          v       l      1
# 8123           o         p                 o          c       l      0
#
#      prediction_label prediction_score
# 8119                e              1.0
# 8120                e              1.0
# 8121                e              1.0
# 8122                p              1.0
# 8123                e              1.0
#
# [5 rows x 25 columns]

# %%
predict_model(best_model, df.tail())
# Out:
#      cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 8119         k           s         n        f    n               a
# 8120         x           s         n        f    n               a
# 8121         f           s         n        f    n               a
# 8122         k           y         n        f    y               f
# 8123         x           s         n        f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ... veil-type veil-color  \
# 8119            c         b          y           e  ...         p          o
# 8120            c         b          y           e  ...         p          n
# 8121            c         b          n           e  ...         p          o
# 8122            c         n          b           t  ...         p          w
# 8123            c         b          y           e  ...         p          o
#
#      ring-number ring-type spore-print-color population habitat target  \
# 8119           o         p                 b          c       l      0
# 8120           o         p                 b          v       l      0
# 8121           o         p                 b          c       l      0
# 8122           o         e                 w          v       l      1
# 8123           o         p                 o          c       l      0
#
#      prediction_label prediction_score
# 8119                e              1.0
# 8120                e              1.0
# 8121                e              1.0
# 8122                p              1.0
# 8123                e              1.0
#
# [5 rows x 25 columns]
